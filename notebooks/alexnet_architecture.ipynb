# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from tensorflow.keras.utils import plot_model

from src.models.alexnet.model import get_alexnet_model

# %%
model = get_alexnet_model(1000)

# %%
plot_model(model, to_file='alexnet.png', show_layer_names=False, show_shapes=True, show_dtype=False, expand_nested=True, rankdir="TB")

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# Image (InputLayer)              [(None, 227, 227, 3) 0
# __________________________________________________________________________________________________
# C1A (Conv2D)                    (None, 55, 55, 48)   17472       Image[0][0]
# __________________________________________________________________________________________________
# C1B (Conv2D)                    (None, 55, 55, 48)   17472       Image[0][0]
# __________________________________________________________________________________________________
# LRN1A (LocalResponseNormalizati (None, 55, 55, 48)   0           C1A[0][0]
# __________________________________________________________________________________________________
# LRN1B (LocalResponseNormalizati (None, 55, 55, 48)   0           C1B[0][0]
# ...
